# %%
# TASK 2:image generation with pre-trained model
# !pip install torch torchvision transformers diffusers accelerate --quiet
# !pip install huggingface_hub --quiet

from diffusers import StableDiffusionPipeline
import torch

model_id = "CompVis/stable-diffusion-v1-4"


pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float32)
pipe = pipe.to("cpu")

# Function to generate image from text
def generate_image(prompt, filename="output.png"):
    image = pipe(prompt).images[0]
    image.save(filename)
    print(f"Image saved as {filename}")

# Example usage
prompt = "A futuristic city skyline at sunset, digital art"
generate_image(prompt, "city.png")
# Out:
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# Fetching 16 files:   0%|          | 0/16 [00:00<?, ?it/s]
# config.json: 0.00B [00:00, ?B/s]
# scheduler_config-checkpoint.json:   0%|          | 0.00/209 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/592 [00:00<?, ?B/s]
# scheduler_config.json:   0%|          | 0.00/313 [00:00<?, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# text_encoder/model.safetensors:   0%|          | 0.00/492M [00:00<?, ?B/s]
# safety_checker/model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/806 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/551 [00:00<?, ?B/s]
# unet/diffusion_pytorch_model.safetensors:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# ...

# %%
from IPython.display import Image, display

display(Image(filename="city.png"))
